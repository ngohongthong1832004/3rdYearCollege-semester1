# %% [markdown]
# 22649011 Ngô Hồng Thông

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2

# %% [markdown]
# ## 1 basic image

# %%
# read img
img = plt.imread('pine.jpg')

# %%
# show img
plt.imshow(img)

# %%
# save img
plt.imsave('pineSave.png', img)

# %% [markdown]
# ## 2 Type of image

# %%
# get the shape of the image
height, width, _ = img.shape
print(f'height: {height}, width: {width}')
# Out:
# height: 1280, width: 960

# %%
# get the red, green, and blue channels
r = img[:, :, 0]
g = img[:, :, 1]
b = img[:, :, 2]
print(f'r: {r.shape}, g: {g.shape}, b: {b.shape}')
# Out:
# r: (1280, 960), g: (1280, 960), b: (1280, 960)

# %%
# Binary and Grayscale Images
# convert to grayscale
gray = np.mean(img, axis=2)
print(f'gray: {gray.shape}')
# Out:
# gray: (1280, 960)

# %%
# color img
plt.imshow(gray, cmap='gray')

# %% [markdown]
# ## 3 Color space

# %%
# show RBG color channels in one plot
plt.figure()
plt.plot(r.flatten(), 'r', label='red')
plt.plot(g.flatten(), 'g', label='green')
plt.plot(b.flatten(), 'b', label='blue')
plt.legend()
# Out:
# C:\Users\thong\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\thong\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# HSV Images

image_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Convert the image from RGB to HSV
hsv = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2HSV)

# Split the HSV image into H, S, and V channels
h, s, v = cv2.split(hsv)

# Plot the original image and the HSV channels
fig, axes = plt.subplots(1, 4, figsize=(20, 5))
axes[0].imshow(image_rgb)
axes[0].set_title("Original Image")
axes[0].axis('off')

axes[1].imshow(h, cmap='gray')
axes[1].set_title("Hue Channel")
axes[1].axis('off')

axes[2].imshow(s, cmap='gray')
axes[2].set_title("Saturation Channel")
axes[2].axis('off')

axes[3].imshow(v, cmap='gray')
axes[3].set_title("Value Channel")
axes[3].axis('off')

plt.show()

# %%
# Ycbcr images
# Convert the image from RGB to YCbCr
ycbcr = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2YCrCb)

# Split the YCbCr image into Y, Cb, and Cr channels
y, cb, cr = cv2.split(ycbcr)

# Plot the original image and the YCbCr channels
fig, axes = plt.subplots(1, 4, figsize=(20, 5))
axes[0].imshow(image_rgb)
axes[0].set_title("Original Image")
axes[0].axis('off')

axes[1].imshow(y, cmap='gray')
axes[1].set_title("Y Channel")
axes[1].axis('off')

axes[2].imshow(cb, cmap='gray')
axes[2].set_title("Cb Channel")
axes[2].axis('off')

axes[3].imshow(cr, cmap='gray')
axes[3].set_title("Cr Channel")
axes[3].axis('off')

plt.show()

# %% [markdown]
# ## 4 Image histogram

# %%
# Histograms equalization
# Convert the image to grayscale
gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

# Apply histogram equalization
equalized = cv2.equalizeHist(gray)

# Plot the original and equalized images
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
axes[0].imshow(gray, cmap='gray')
axes[0].set_title("Original Image")
axes[0].axis('off')

axes[1].imshow(equalized, cmap='gray')
axes[1].set_title("Equalized Image")
axes[1].axis('off')

plt.show()

# %%
# Contrast limited adaptive histogram equalization (CLAHE)
# Create a CLAHE object
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))

# Apply CLAHE
clahe_img = clahe.apply(gray)

# Plot the original and CLAHE images
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
axes[0].imshow(gray, cmap='gray')
axes[0].set_title("Original Image")
axes[0].axis('off')

axes[1].imshow(clahe_img, cmap='gray')
axes[1].set_title("CLAHE Image")
axes[1].axis('off')

plt.show()
