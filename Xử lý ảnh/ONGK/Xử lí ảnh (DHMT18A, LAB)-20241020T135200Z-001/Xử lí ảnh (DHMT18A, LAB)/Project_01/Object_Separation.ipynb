# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image = cv2.imread('/content/drive/MyDrive/Xử lí ảnh (DHMT18A, LAB)/Project_01/image/img_3.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()

# %%
temp = image.flatten()
med = np.mean(temp)
med
# Out:
# 204.72041736084412

# %%
image = np.where(image <= med, 255, 0)

# %%
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()
