# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
letter_b = np.ones((300, 300), dtype=np.uint8) * 255
plt.imshow(letter_b, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.show()

# %%
letter_b[50:300, 50:100] = 0
letter_b[50:100, 100:200] = 0
letter_b[100:150, 150:200] = 0
letter_b[150:200, 100:200] = 0
letter_b[200:300, 150:200] = 0
letter_b[250:300, 100:150] = 0

plt.imshow(letter_b, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
plt.show()
