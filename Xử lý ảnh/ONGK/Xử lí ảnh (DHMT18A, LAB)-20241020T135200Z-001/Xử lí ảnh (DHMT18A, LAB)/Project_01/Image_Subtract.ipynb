# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
circle = cv2.imread('/content/drive/MyDrive/Xử lí ảnh (DHMT18A, LAB)/Project_01/image/circle.png')
star = cv2.imread('/content/drive/MyDrive/Xử lí ảnh (DHMT18A, LAB)/Project_01/image/star.png')

# %%
subtract = star - circle
# plt.imshow(subtract)
# plt.axis('off')
# plt.show()
plt.figure(figsize=(12,8))

plt.subplot(1,3,1)
plt.imshow(circle)

plt.subplot(1,3,2)
plt.imshow(star)

plt.subplot(1,3,3)
plt.imshow(subtract)

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def rotate_image(image, angle):
    # Lấy kích thước ảnh
    (h, w) = image.shape[:2]

    # Tìm tâm của ảnh
    center = (w / 2, h / 2)

    # Tạo ma trận xoay
    M = cv2.getRotationMatrix2D(center, angle, 1.0)

    # Áp dụng ma trận affine lên ảnh
    rotated = cv2.warpAffine(image, M, (w, h))

    return rotated

# Đọc ảnh bằng OpenCV
image = cv2.imread("/content/drive/MyDrive/Xử lí ảnh (DHMT18A, LAB)/Project_01/image/img_1.png")

# Xoay ảnh với góc 45 độ
rotated_image = rotate_image(image, 40)

# Chuyển đổi ảnh từ BGR sang RGB
rotated_image_rgb = cv2.cvtColor(rotated_image, cv2.COLOR_BGR2RGB)

# Hiển thị ảnh bằng matplotlib
plt.imshow(rotated_image_rgb)
plt.title('Rotated Image')
plt.axis('off') # Tắt trục tọa độ
plt.show()
